# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
import torch.nn.functional as func

# %%
a=np.array(([1.,3.],[0,0]))

# %%
a
# Out:
# array([[ 1.,  3.],
#        [ 4.,  5.]])

# %%
b=torch.from_numpy(a)

# %%
b
# Out:
#  1  3
#  0  0
# [torch.DoubleTensor of size 2x2]

# %%
b_norm=func.normalize(b,dim=1)

# %%
b_norm
# Out:
#  0.3162  0.9487
#  0.0000  0.0000
# [torch.DoubleTensor of size 2x2]

# %%
torch.norm(b_norm[:,0])
# Out:
# 1.0

# %%
b_norm[0]
# Out:
#  0.3162
#  0.9487
# [torch.DoubleTensor of size 2]

# %%
c=np.array((0.2425,0.9701))

# %%
np.linalg.norm(c)
# Out:
# 0.99995012875642952

# %%
loss_collector=np.load('loss_1HL_32U.npy')
grad_collector=np.load('grads_1HL_32U.npy')
EV_collector=np.load('EVs_1HL_32U.npy')

# %%
loss_collector=np.load('loss_1HL_16U.npy')
grad_collector=np.load('grads_1HL_16U.npy')
EV_collector=np.load('EVs_1HL_16U.npy')

# %%
fig = plt.figure()
plt.subplot(1, 3, 1)
plt.plot(np.arange(len(loss_collector)),loss_collector)
plt.title('LOSS')
plt.subplot(1, 3, 2)
plt.plot(np.arange(len(grad_collector)),grad_collector)
plt.title('|GRAD|')

plt.subplot(1, 3, 3)

plt.plot(np.arange(len(EV_collector)), EV_collector[:,0])
plt.plot(np.arange(len(EV_collector)), EV_collector[:,1],':')
plt.title('|EVs|')


plt.subplots_adjust(left=4, right=6)
# Out:
# /home/jonas/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
